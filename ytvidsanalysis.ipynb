# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle

# %%
! cp /content/drive/MyDrive/KaggleAPI/kaggle.json  ~/.kaggle/

# %%
! kaggle datasets download -d datasnaek/youtube-new
# Out:
# ...
#  92% 185M/201M [00:01<00:00, 138MB/s]
# 100% 201M/201M [00:01<00:00, 129MB/s]

# %%
! unzip /content/youtube-new.zip
# Out:
# Archive:  /content/youtube-new.zip
#   inflating: CA_category_id.json
#   inflating: CAvideos.csv
#   inflating: DE_category_id.json
#   inflating: DEvideos.csv
#   inflating: FR_category_id.json
#   inflating: FRvideos.csv
#   inflating: GB_category_id.json
#   inflating: GBvideos.csv
#   inflating: IN_category_id.json
#   inflating: INvideos.csv
#   inflating: JP_category_id.json
#   inflating: JPvideos.csv
#   inflating: KR_category_id.json
#   inflating: KRvideos.csv
#   inflating: MX_category_id.json
#   inflating: MXvideos.csv
#   inflating: RU_category_id.json
#   inflating: RUvideos.csv
#   inflating: US_category_id.json
#   inflating: USvideos.csv

# %%
import pandas as pd
import numpy as np

# %%
vids=pd.read_csv('USvideos.csv')

# %%
vids.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
vids.head(10).drop(columns=['category_id', 'thumbnail_link', 'video_error_or_removed', 'video_id'])
# Out:
#   trending_date                                              title  \
# 0      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                   Nickelback Lyrics: Real or Fake?
# 4      17.14.11                           I Dare You: GOING BALD!?
# 5      17.14.11                              2 Weeks with iPhone X
# 6      17.14.11          Roy Moore & Jeff Sessions Cold Open - SNL
# 7      17.14.11                5 Ice Cream Gadgets put to the Test
# 8      17.14.11  The Greatest Showman | Official Trailer 2 [HD]...
# 9      17.14.11  Why the rise of the robots won’t mean the end ...
#
#            channel_title              publish_time  \
# 0           CaseyNeistat  2017-11-13T17:13:01.000Z
# 1        LastWeekTonight  2017-11-13T07:30:00.000Z
# 2           Rudy Mancuso  2017-11-12T19:05:24.000Z
# ...

# %%
vids.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
vids.shape
# Out:
# (40949, 16)

# %%
vids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
vids.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
vids.index
# Out:
# RangeIndex(start=0, stop=40949, step=1)

# %%
vids[["comment_count","views","likes","dislikes"]].mean()
# Out:
# comment_count    8.446804e+03
# views            2.360785e+06
# likes            7.426670e+04
# dislikes         3.711401e+03
# dtype: float64

# %%
#to see correlations between views and positive/negative engagement.

import matplotlib.pyplot as plt

# Views vs. Likes
plt.figure(figsize=(10, 6))
plt.scatter(vids['views'], vids['likes'], alpha=0.5)
plt.xlabel('Views')
plt.ylabel('Likes')
plt.title('Views vs. Likes')
plt.show()

# Views vs. Dislikes
plt.figure(figsize=(10, 6))
plt.scatter(vids['views'], vids['dislikes'], alpha=0.5)
plt.xlabel('Views')
plt.ylabel('Dislikes')
plt.title('Views vs. Dislikes')
plt.show()

# Correlation coefficients
print('Correlation between views and likes:', vids['views'].corr(vids['likes']))
print('Correlation between views and dislikes:', vids['views'].corr(vids['dislikes']))
# Out:
# Correlation between views and likes: 0.8491765212088975
# Correlation between views and dislikes: 0.4722132456459324

# %%
#to see correlation between views and discussion.

# Views vs. Comments
plt.figure(figsize=(10, 6))
plt.scatter(vids['views'], vids['comment_count'], alpha=0.5)
plt.xlabel('Views')
plt.ylabel('Comments')
plt.title('Views vs. Comments')
plt.show()

# Correlation coefficient
print('Correlation between views and comments:', vids['views'].corr(vids['comment_count']))
# Out:
# Correlation between views and comments: 0.6176212718159843

# %%
#frequently used keywords to understand content themes
from wordcloud import WordCloud

# Combine title and tags into a single string
text = ""
for i in range(len(vids)):
  text += vids.loc[i]['title'] + " " + vids.loc[i]['tags']

# Generate word cloud
wordcloud = WordCloud(width=800, height=400).generate(text)

# Display the word cloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Extract and print frequent words
words = wordcloud.words_
frequent_words = dict(sorted(words.items(), key=lambda item: item[1], reverse=True))

print("Frequent words:")
for word, frequency in frequent_words.items():
  print(f"{word}: {frequency}")
# Out:
# Frequent words:
# music video: 1.0
# Official Video: 0.896551724137931
# star wars: 0.7791461412151067
# Official Trailer: 0.6707717569786535
# makeup tutorial: 0.6555829228243021
# super bowl: 0.6235632183908046
# will smith: 0.5242200328407225
# black panther: 0.5155993431855501
# funny video: 0.5139573070607554
# late night: 0.5073891625615764
# talk show: 0.5045155993431856
# make: 0.4876847290640394
# new york: 0.4585385878489327
# dude perfect: 0.4577175697865353
# charlie puth: 0.4281609195402299
# Cardi B: 0.41461412151067323
# last jedi: 0.4039408866995074
# Lyric Video: 0.40106732348111657
# Late Show: 0.38095238095238093
# iphone x: 0.37561576354679804
# youtube youtube: 0.3731527093596059
# shawn mendes: 0.3715106732348112
# life noggin: 0.3645320197044335
# kim kardashian: 0.3530377668308703
# Graham Norton: 0.3522167487684729
# Official Music: 0.3497536945812808
# infinity war: 0.3448275862068966
# family friendly: 0.33866995073891626
# full face: 0.3206075533661741
# ...

# %%
_df_30['views'].plot(kind='hist', bins=20, title='views')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_31['likes'].plot(kind='hist', bins=20, title='likes')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_32['dislikes'].plot(kind='hist', bins=20, title='dislikes')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_33['comment_count'].plot(kind='hist', bins=20, title='comment_count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_34.plot(kind='scatter', x='views', y='likes', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_35.plot(kind='scatter', x='likes', y='dislikes', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
_df_36.plot(kind='scatter', x='dislikes', y='comment_count', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Select relevant numerical columns
numerical_cols = ['category_id', 'views', 'likes', 'dislikes', 'comment_count',
                  'comments_disabled', 'ratings_disabled']

# Assuming you have loaded the data into a pandas dataframe 'df'
sample_row = vids.sample(1)

# Extract feature vector
feature_vector = sample_row[numerical_cols].values[0]

print("Feature Vector:")
print(feature_vector)
# Out:
# Feature Vector:
# [10 3800486 229633 4010 12871 False False]

# %%
numerical_cols = ['category_id', 'views', 'likes', 'dislikes', 'comment_count',
                  'comments_disabled', 'ratings_disabled']

sample_row = vids.sample(5)

feature_vector = sample_row[numerical_cols].values[0]

print("Feature Vector:")
print(feature_vector)
# Out:
# Feature Vector:
# [26 413878 20931 644 1965 False False]

# %%
numerical_cols = ['views', 'likes', 'dislikes', 'comment_count']

sample_row = vids.sample(33)

feature_vector = sample_row[numerical_cols].values[0]

normalized_feature_vector = (feature_vector - feature_vector.min()) / (feature_vector.max() - feature_vector.min())

print("Normalized Feature Vector:")
print(normalized_feature_vector)

# Apply feature scaling to the entire dataset
normalized_df = vids[numerical_cols].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

print("Normalized DataFrame:")
print(normalized_df.head())
# Out:
# Normalized Feature Vector:
# [1.         0.02509007 0.         0.00156174]
# Normalized DataFrame:
#       views     likes  dislikes  comment_count
# 0  0.003321  0.010247  0.001771       0.011717
# 1  0.010738  0.017312  0.003671       0.009330
# 2  0.014168  0.026013  0.003189       0.006008
# 3  0.001521  0.001812  0.000398       0.001576
# 4  0.009303  0.023555  0.001188       0.012866

# %%
vids.shape
# Out:
# (40949, 16)

# %%
vids.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
Relevant_features=vids[["title","channel_title","trending_date","tags","views","likes","dislikes","comment_count","description"]]

# %%
Relevant_features
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title trending_date  \
# 0                  CaseyNeistat      17.14.11
# 1               LastWeekTonight      17.14.11
# 2                  Rudy Mancuso      17.14.11
# 3         Good Mythical Morning      17.14.11
# ...

# %%
list_of_relevant_features=Relevant_features.columns.tolist()

# %%
list_of_relevant_features
# Out:
# ['title',
#  'channel_title',
#  'trending_date',
#  'tags',
#  'views',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'description']

# %%
vids.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
Irrelevant_features=vids[["video_id","publish_time","category_id","thumbnail_link","comments_disabled", "ratings_disabled","video_error_or_removed"]]

# %%
Irrelevant_features
# Out:
#           video_id              publish_time  category_id  \
# 0      2kyS6SvSYSE  2017-11-13T17:13:01.000Z           22
# 1      1ZAPwfrtAFY  2017-11-13T07:30:00.000Z           24
# 2      5qpjK5DgCt4  2017-11-12T19:05:24.000Z           23
# 3      puqaWrEC7tY  2017-11-13T11:00:04.000Z           24
# 4      d380meD0W0M  2017-11-12T18:01:41.000Z           24
# ...            ...                       ...          ...
# 40944  BZt0qjTWNhw  2018-05-18T13:00:04.000Z           15
# 40945  1h7KV2sjUWY  2018-05-18T01:00:06.000Z           22
# 40946  D6Oy4LfoqsU  2018-05-18T17:34:22.000Z           24
# 40947  oV0zkMe1K8s  2018-05-17T17:00:04.000Z            1
# 40948  ooyjaVdt-jA  2018-05-17T17:09:38.000Z           20
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# ...

# %%
list_of_irrelevant_features=Irrelevant_features.columns.tolist()

# %%
list_of_irrelevant_features
# Out:
# ['video_id',
#  'publish_time',
#  'category_id',
#  'thumbnail_link',
#  'comments_disabled',
#  'ratings_disabled',
#  'video_error_or_removed']
